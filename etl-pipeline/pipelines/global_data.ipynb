# %%
import os
import shutil
import sys
import pandas as pd
import numpy as np

from datetime import datetime
import covid_etl as transforms

# %%
INPUT_DATA_DIR = os.path.join(os.path.abspath('../../../'),
                        'COVID-19',
                        'csse_covid_19_data',
                        'csse_covid_19_daily_reports')
print("Input Dir: " + INPUT_DATA_DIR)
# Out:
# Input Dir: /Users/adammcquistan/code/ambassador/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports

# %%
TRANSFORMED_DATA_DIR = os.path.join(os.path.abspath('../../../'), 'COVID-19-TRANSFORMED')

if os.path.exists(TRANSFORMED_DATA_DIR):
    shutil.rmtree(TRANSFORMED_DATA_DIR)

os.makedirs(TRANSFORMED_DATA_DIR)

print("Output Dir: " + TRANSFORMED_DATA_DIR)
# Out:
# Output Dir: /Users/adammcquistan/code/ambassador/COVID-19-TRANSFORMED

# %%
# Fix any BOM files (there are some early on ones in Jan 2020, could be more later)

input_files = [f for f in os.listdir(INPUT_DATA_DIR) if f.endswith('.csv')]

for f in input_files:
    input_f = os.path.join(INPUT_DATA_DIR, f)
    output_f = os.path.join(TRANSFORMED_DATA_DIR, 'global_'+f)
    with open(input_f, mode='r', encoding='utf-8-sig') as fin, open(output_f, mode='w', encoding='utf-8') as fout:
        fout.write(fin.read())

# %%
# remap headers to consistent format

files = [f for f in os.listdir(TRANSFORMED_DATA_DIR) if f.startswith('global_')]

for f in files:
    fname, fext = os.path.splitext(f)
    date_str = fname.replace('global_', '')
    file_path = os.path.join(TRANSFORMED_DATA_DIR, f)
    with open(file_path) as fp:
        headers = fp.readline().strip()
        if headers not in transforms.known_headers:
            print("{} has unrecognized headers {}".format(f, headers))
            sys.exit(1)

        print('Transforming {}'.format(f))
        df = pd.read_csv(file_path)
        transformed_df = transforms.transform_headers(df, date_str)
    transformed_path = os.path.join(TRANSFORMED_DATA_DIR, 'transformed_'+date_str+'.csv')
    transformed_df.to_csv(transformed_path)
# Out:
# Transforming global_04-17-2020.csv
# Transforming global_04-16-2020.csv
# Transforming global_07-24-2020.csv
# Transforming global_07-25-2020.csv
# Transforming global_08-01-2020.csv
# Transforming global_06-18-2020.csv
# Transforming global_06-19-2020.csv
# Transforming global_11-22-2020.csv
# Transforming global_11-23-2020.csv
# Transforming global_03-05-2020.csv
# Transforming global_03-04-2020.csv
# Transforming global_10-20-2020.csv
# Transforming global_10-21-2020.csv
# Transforming global_09-03-2020.csv
# Transforming global_09-02-2020.csv
# Transforming global_04-29-2020.csv
# Transforming global_04-28-2020.csv
# Transforming global_05-15-2020.csv
# Transforming global_05-14-2020.csv
# Transforming global_06-26-2020.csv
# Transforming global_06-27-2020.csv
# Transforming global_02-07-2020.csv
# Transforming global_02-06-2020.csv
# Transforming global_05-21-2020.csv
# Transforming global_05-20-2020.csv
# Transforming global_06-12-2020.csv
# Transforming global_06-13-2020.csv
# Transforming global_11-28-2020.csv
# Transforming global_11-29-2020.csv
# Transforming global_10-14-2020.csv
# Transforming global_10-15-2020.csv
# Transforming global_03-31-2020.csv
# Transforming global_03-30-2020.csv
# Transforming global_11-16-2020.csv
# Transforming global_11-17-2020.csv
# Transforming global_04-23-2020.csv
# Transforming global_04-22-2020.csv
# Transforming global_09-09-2020.csv
# Transforming global_07-10-2020.csv
# Transforming global_07-11-2020.csv
# Transforming global_09-08-2020.csv
# Transforming global_03-12-2020.csv
# Transforming global_03-13-2020.csv
# Transforming global_08-16-2020.csv
# Transforming global_08-17-2020.csv
# Transforming global_04-01-2020.csv
# Transforming global_10-09-2020.csv
# Transforming global_10-08-2020.csv
# Transforming global_02-10-2020.csv
# Transforming global_02-11-2020.csv
# Transforming global_01-23-2020.csv
# Transforming global_01-22-2020.csv
# Transforming global_05-02-2020.csv
# Transforming global_05-03-2020.csv
# Transforming global_08-28-2020.csv
# Transforming global_06-30-2020.csv
# Transforming global_08-29-2020.csv
# Transforming global_09-14-2020.csv
# Transforming global_09-15-2020.csv
# Transforming global_10-03-2020.csv
# Transforming global_10-02-2020.csv
# Transforming global_09-20-2020.csv
# Transforming global_09-21-2020.csv
# Transforming global_06-05-2020.csv
# Transforming global_06-04-2020.csv
# Transforming global_03-18-2020.csv
# Transforming global_03-19-2020.csv
# Transforming global_02-24-2020.csv
# Transforming global_02-25-2020.csv
# Transforming global_07-07-2020.csv
# Transforming global_07-06-2020.csv
# Transforming global_08-22-2020.csv
# Transforming global_08-23-2020.csv
# Transforming global_11-01-2020.csv
# Transforming global_05-08-2020.csv
# Transforming global_05-09-2020.csv
# Transforming global_03-26-2020.csv
# Transforming global_03-27-2020.csv
# Transforming global_01-29-2020.csv
# Transforming global_01-28-2020.csv
# Transforming global_03-15-2020.csv
# Transforming global_03-14-2020.csv
# Transforming global_02-29-2020.csv
# Transforming global_02-28-2020.csv
# Transforming global_04-07-2020.csv
# Transforming global_04-06-2020.csv
# Transforming global_06-08-2020.csv
# Transforming global_08-11-2020.csv
# Transforming global_08-10-2020.csv
# Transforming global_06-09-2020.csv
# Transforming global_12-01-2020.csv
# Transforming global_02-17-2020.csv
# Transforming global_02-16-2020.csv
# Transforming global_01-24-2020.csv
# Transforming global_01-25-2020.csv
# Transforming global_09-13-2020.csv
# Transforming global_09-12-2020.csv
# Transforming global_10-30-2020.csv
# Transforming global_10-31-2020.csv
# Transforming global_05-05-2020.csv
# Transforming global_05-04-2020.csv
# Transforming global_05-31-2020.csv
# Transforming global_05-30-2020.csv
# Transforming global_06-02-2020.csv
# Transforming global_06-03-2020.csv
# Transforming global_10-04-2020.csv
# Transforming global_10-05-2020.csv
# Transforming global_09-27-2020.csv
# Transforming global_09-26-2020.csv
# Transforming global_02-23-2020.csv
# Transforming global_02-22-2020.csv
# Transforming global_08-25-2020.csv
# Transforming global_08-24-2020.csv
# Transforming global_11-06-2020.csv
# Transforming global_11-07-2020.csv
# Transforming global_09-19-2020.csv
# Transforming global_09-18-2020.csv
# Transforming global_07-01-2020.csv
# Transforming global_03-21-2020.csv
# Transforming global_03-20-2020.csv
# Transforming global_08-06-2020.csv
# Transforming global_08-07-2020.csv
# Transforming global_11-25-2020.csv
# Transforming global_11-24-2020.csv
# Transforming global_04-10-2020.csv
# Transforming global_04-11-2020.csv
# Transforming global_07-23-2020.csv
# Transforming global_07-22-2020.csv
# Transforming global_10-19-2020.csv
# Transforming global_10-18-2020.csv
# Transforming global_03-02-2020.csv
# Transforming global_03-03-2020.csv
# Transforming global_05-12-2020.csv
# Transforming global_05-13-2020.csv
# Transforming global_06-21-2020.csv
# Transforming global_06-20-2020.csv
# Transforming global_10-27-2020.csv
# Transforming global_10-26-2020.csv
# Transforming global_09-04-2020.csv
# Transforming global_09-05-2020.csv
# Transforming global_02-01-2020.csv
# Transforming global_03-08-2020.csv
# Transforming global_03-09-2020.csv
# Transforming global_07-29-2020.csv
# Transforming global_09-30-2020.csv
# Transforming global_07-28-2020.csv
# Transforming global_10-13-2020.csv
# Transforming global_10-12-2020.csv
# Transforming global_05-26-2020.csv
# Transforming global_05-27-2020.csv
# Transforming global_06-15-2020.csv
# Transforming global_06-14-2020.csv
# Transforming global_04-24-2020.csv
# Transforming global_04-25-2020.csv
# Transforming global_07-17-2020.csv
# Transforming global_07-16-2020.csv
# Transforming global_11-11-2020.csv
# Transforming global_11-10-2020.csv
# Transforming global_05-18-2020.csv
# Transforming global_05-19-2020.csv
# Transforming global_04-09-2020.csv
# Transforming global_04-08-2020.csv
# Transforming global_10-01-2020.csv
# Transforming global_09-23-2020.csv
# Transforming global_09-22-2020.csv
# Transforming global_06-06-2020.csv
# Transforming global_06-07-2020.csv
# Transforming global_02-27-2020.csv
# Transforming global_02-26-2020.csv
# Transforming global_07-04-2020.csv
# Transforming global_07-05-2020.csv
# Transforming global_08-21-2020.csv
# Transforming global_08-20-2020.csv
# Transforming global_11-02-2020.csv
# Transforming global_11-03-2020.csv
# Transforming global_03-25-2020.csv
# Transforming global_03-24-2020.csv
# Transforming global_02-19-2020.csv
# Transforming global_02-18-2020.csv
# Transforming global_03-11-2020.csv
# Transforming global_03-10-2020.csv
# Transforming global_08-15-2020.csv
# Transforming global_08-14-2020.csv
# Transforming global_09-29-2020.csv
# Transforming global_07-30-2020.csv
# Transforming global_07-31-2020.csv
# Transforming global_09-28-2020.csv
# Transforming global_04-03-2020.csv
# Transforming global_04-02-2020.csv
# Transforming global_02-13-2020.csv
# Transforming global_02-12-2020.csv
# Transforming global_11-08-2020.csv
# Transforming global_11-09-2020.csv
# Transforming global_05-01-2020.csv
# Transforming global_09-17-2020.csv
# Transforming global_09-16-2020.csv
# Transforming global_08-08-2020.csv
# Transforming global_06-11-2020.csv
# Transforming global_06-10-2020.csv
# Transforming global_08-09-2020.csv
# Transforming global_05-22-2020.csv
# Transforming global_05-23-2020.csv
# Transforming global_10-17-2020.csv
# Transforming global_10-16-2020.csv
# Transforming global_11-15-2020.csv
# Transforming global_11-14-2020.csv
# Transforming global_10-29-2020.csv
# Transforming global_10-28-2020.csv
# Transforming global_07-13-2020.csv
# Transforming global_07-12-2020.csv
# Transforming global_04-20-2020.csv
# Transforming global_04-21-2020.csv
# Transforming global_07-27-2020.csv
# Transforming global_07-26-2020.csv
# Transforming global_04-14-2020.csv
# Transforming global_04-15-2020.csv
# Transforming global_05-28-2020.csv
# Transforming global_05-29-2020.csv
# Transforming global_08-02-2020.csv
# Transforming global_08-03-2020.csv
# Transforming global_11-21-2020.csv
# Transforming global_11-20-2020.csv
# Transforming global_03-06-2020.csv
# Transforming global_03-07-2020.csv
# Transforming global_10-23-2020.csv
# Transforming global_10-22-2020.csv
# Transforming global_07-19-2020.csv
# Transforming global_07-18-2020.csv
# Transforming global_09-01-2020.csv
# Transforming global_06-25-2020.csv
# Transforming global_06-24-2020.csv
# Transforming global_05-16-2020.csv
# Transforming global_05-17-2020.csv
# Transforming global_02-04-2020.csv
# Transforming global_02-05-2020.csv
# Transforming global_04-19-2020.csv
# Transforming global_04-18-2020.csv
# Transforming global_10-10-2020.csv
# Transforming global_10-11-2020.csv
# Transforming global_06-16-2020.csv
# Transforming global_06-17-2020.csv
# Transforming global_05-25-2020.csv
# Transforming global_05-24-2020.csv
# Transforming global_02-09-2020.csv
# Transforming global_02-08-2020.csv
# Transforming global_07-14-2020.csv
# Transforming global_07-15-2020.csv
# Transforming global_04-27-2020.csv
# Transforming global_04-26-2020.csv
# Transforming global_11-12-2020.csv
# Transforming global_11-13-2020.csv
# Transforming global_06-28-2020.csv
# Transforming global_08-31-2020.csv
# Transforming global_08-30-2020.csv
# Transforming global_06-29-2020.csv
# Transforming global_08-05-2020.csv
# Transforming global_08-04-2020.csv
# Transforming global_11-26-2020.csv
# Transforming global_11-27-2020.csv
# Transforming global_07-20-2020.csv
# Transforming global_07-21-2020.csv
# Transforming global_04-13-2020.csv
# Transforming global_04-12-2020.csv
# Transforming global_03-01-2020.csv
# Transforming global_11-18-2020.csv
# Transforming global_11-19-2020.csv
# Transforming global_06-22-2020.csv
# Transforming global_06-23-2020.csv
# Transforming global_05-11-2020.csv
# Transforming global_05-10-2020.csv
# Transforming global_10-24-2020.csv
# Transforming global_10-25-2020.csv
# Transforming global_09-07-2020.csv
# Transforming global_09-06-2020.csv
# Transforming global_01-30-2020.csv
# Transforming global_01-31-2020.csv
# Transforming global_02-03-2020.csv
# Transforming global_02-02-2020.csv
# Transforming global_06-01-2020.csv
# Transforming global_08-18-2020.csv
# Transforming global_08-19-2020.csv
# Transforming global_10-07-2020.csv
# Transforming global_10-06-2020.csv
# Transforming global_09-24-2020.csv
# Transforming global_09-25-2020.csv
# Transforming global_02-20-2020.csv
# Transforming global_02-21-2020.csv
# Transforming global_08-26-2020.csv
# Transforming global_08-27-2020.csv
# Transforming global_11-05-2020.csv
# Transforming global_11-04-2020.csv
# Transforming global_07-03-2020.csv
# Transforming global_07-02-2020.csv
# Transforming global_04-30-2020.csv
# Transforming global_03-22-2020.csv
# Transforming global_03-23-2020.csv
# Transforming global_03-16-2020.csv
# Transforming global_03-17-2020.csv
# Transforming global_04-04-2020.csv
# Transforming global_04-05-2020.csv
# Transforming global_12-02-2020.csv
# Transforming global_12-03-2020.csv
# Transforming global_11-30-2020.csv
# Transforming global_08-12-2020.csv
# Transforming global_08-13-2020.csv
# Transforming global_03-28-2020.csv
# Transforming global_03-29-2020.csv
# Transforming global_01-27-2020.csv
# Transforming global_01-26-2020.csv
# Transforming global_02-14-2020.csv
# Transforming global_02-15-2020.csv
# Transforming global_07-09-2020.csv
# Transforming global_09-10-2020.csv
# Transforming global_09-11-2020.csv
# Transforming global_07-08-2020.csv
# Transforming global_05-06-2020.csv
# Transforming global_05-07-2020.csv

# %%
transformed_df.head()
# Out:
#         date  city           state country   latitude   longitude  cases  \
# 0 2020-05-07   NaN  South Carolina      US  34.223334  -82.461707     34
# 1 2020-05-07   NaN       Louisiana      US  30.295065  -92.414197    142
# 2 2020-05-07   NaN        Virginia      US  37.767072  -75.632346    463
# 3 2020-05-07   NaN           Idaho      US  43.452658 -116.241552    721
# 4 2020-05-07   NaN            Iowa      US  41.330756  -94.471059      3
#
#    deaths  recoveries  testing_rate  hospitalization_rate  cases_100K  \
# 0       0           0           NaN                   NaN         NaN
# 1      11           0           NaN                   NaN         NaN
# 2       7           0           NaN                   NaN         NaN
# 3      19           0           NaN                   NaN         NaN
# 4       0           0           NaN                   NaN         NaN
#
#                     combined_key     FIPS  UID
# 0  abbeville, south carolina, us  45001.0  NaN
# 1          acadia, louisiana, us  22001.0  NaN
# 2         accomack, virginia, us  51001.0  NaN
# 3                 ada, idaho, us  16001.0  NaN
# 4                adair, iowa, us  19001.0  NaN
